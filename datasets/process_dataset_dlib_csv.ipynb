# %%
import os
import cv2
import imutils
from imutils import face_utils
import dlib
import glob2
import matplotlib.pyplot as plt
import pandas as pd
from scipy.spatial import distance as dist

# %%
DATASET = './dmd/binary_labels'
CSV_FILE = 'landmarks_ratios.csv'
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('dlib/shape_predictor_68_face_landmarks.dat')

EYE_AR_THRESH = 0.3
MOUTH_AR_THRESH = 0.2

# %%
def get_landmarks_ratios(frame):

    frame = imutils.resize(frame, width=640)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # detect faces
    faces = detector(gray)
    print(f'Faces: {len(faces)}')

    if len(faces) == 0:
        return None

    # get the largest face
    largest_face = None;
    for face in faces:
        largest_face_area = 0;
        if face.area() > largest_face_area:
            largest_face = face

    shape = predictor(gray, largest_face)

    # Extracting the indices of the facial features
    (lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS["left_eye"]
    (rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS["right_eye"]
    (mStart, mEnd) = face_utils.FACIAL_LANDMARKS_IDXS["inner_mouth"]

    # Get coordinates for left eye, right eye, and mouth
    left_eye = [(shape.part(i).x, shape.part(i).y) for i in range(lStart, lEnd)]
    right_eye = [(shape.part(i).x, shape.part(i).y) for i in range(rStart, rEnd)]
    mouth = [(shape.part(i).x, shape.part(i).y) for i in range(mStart, mEnd)]

    # Compute aspect ratios for the eyes and mouth
    def eye_aspect_ratio(eye):
        A = dist.euclidean(eye[1], eye[5])
        B = dist.euclidean(eye[2], eye[4])
        C = dist.euclidean(eye[0], eye[3])
        ear = (A + B) / (2.0 * C)
        return ear

    def mouth_aspect_ratio(mouth):
        A = dist.euclidean(mouth[2], mouth[6])
        C = dist.euclidean(mouth[0], mouth[4])
        mar = A / C
        return mar

    left_ear = eye_aspect_ratio(left_eye)
    right_ear = eye_aspect_ratio(right_eye)
    mouth_ar = mouth_aspect_ratio(mouth)

    return left_ear, right_ear, mouth_ar

# %%
if os.path.exists(CSV_FILE):
    csv = pd.read_csv
else:
    # Create a DataFrame to hold the data
    df = pd.DataFrame(columns=["Image", "Left_Eye_AR", "Right_Eye_AR", "Mouth_AR", "Awake"])
    file_paths = glob2.glob(DATASET + '/**/*.jpg')
    data = []

    for i, file_path in enumerate(file_paths):

        awake = 1 if 'awake' in file_path else 0
        print(f'Awake: {awake}')
        img = cv2.imread(file_path)
        ratios = get_landmarks_ratios(img)

        if img is not None and ratios is not None:
            # for ratio in ratios:

            print(f"{ratios}\n")
            if img is not None and ratios is not None:
                row = {
                    "Image": file_path,
                    "Left_Eye_AR": ratios[0],
                    "Right_Eye_AR": ratios[1],
                    "Mouth_AR": ratios[2],
                    "Awake": awake
                }
                data.append(row)


    df = pd.concat([df, pd.DataFrame(data)], ignore_index=True)  # concatenate the new data with the old dataframe

    df.to_csv('landmarks_ratios.csv', index=False)
# Out:
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1800020524176937, 0.2055270768301462, 0.3022438607339301)
#
# Awake: 0
# Faces: 1
# (0.2805283198220218, 0.2487592975524973, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.3078314151048782, 0.2890735821752002, 0.6206896551724138)
#
# Awake: 0
# Faces: 1
# (0.3820018448736402, 0.3859651178085249, 0.07895830523185818)
#
# Awake: 0
# Faces: 1
# (0.2631578947368421, 0.26430342040599236, 0.08789381029635715)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.26539634065922857, 0.2028242685634354, 0.03006244442563018)
#
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.22800237002164542, 0.8275862068965517)
#
# Awake: 0
# Faces: 1
# (0.2326803115618832, 0.2381322242764817, 0.03423934786989504)
#
# Awake: 0
# Faces: 1
# (0.24961508830135312, 0.2102353324910547, 0.06575248692937263)
#
# Awake: 0
# Faces: 1
# (0.21347047650771073, 0.2111500763274038, 0.0)
#
# Awake: 0
# Faces: 1
# (0.11043152607484653, 0.12437964877624864, 0.027735009811261455)
#
# Awake: 0
# Faces: 1
# (0.11694886282802262, 0.17616606585441102, 0.32558139534883723)
#
# Awake: 0
# Faces: 1
# (0.31796743500784785, 0.3333333333333333, 0.06381534447172756)
#
# Awake: 0
# Faces: 1
# (0.3505237427021916, 0.2800964052936168, 0.6790776809874453)
#
# Awake: 0
# Faces: 1
# (0.18569533817705186, 0.22376876883610253, 0.048308615039636994)
#
# Awake: 0
# Faces: 1
# (0.27607881518711636, 0.2617119612951069, 0.5513964134364621)
#
# Awake: 0
# Faces: 1
# (0.275, 0.2744055969546628, 0.3333333333333333)
#
# Awake: 0
# Faces: 1
# (0.2996257016633534, 0.3178536264305499, 0.05086572639414618)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.22188007849009164, 0.035623524993954825)
#
# Awake: 0
# Faces: 1
# (0.32636898871828884, 0.29584971897989776, 0.023199420949679552)
#
# Awake: 0
# Faces: 1
# (0.19376237877321473, 0.18719105994632887, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.2719574970387818, 0.6662966046527695)
#
# Awake: 0
# Faces: 1
# (0.2949955097939174, 0.26430342040599236, 0.6781390797358372)
#
# Awake: 0
# Faces: 1
# (0.11043152607484653, 0.12437964877624864, 0.027777777777777776)
#
# Awake: 0
# Faces: 1
# (0.26354602406911043, 0.22529441422441898, 0.7387168551531178)
#
# Awake: 0
# Faces: 1
# (0.15768735977629134, 0.16439898730535732, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2139062186164015, 0.22529441422441898, 0.0)
#
# Awake: 0
# Faces: 1
# (0.14680505487867587, 0.1334655061609511, 0.031113569564352756)
#
# Awake: 0
# Faces: 1
# (0.23684210526315788, 0.2777777777777778, 0.2)
#
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.27363522730774703, 0.766241095350685)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.26424909878161656, 0.07894736842105263)
#
# Awake: 0
# Faces: 1
# (0.3055555555555556, 0.30262874684312724, 0.6888804054534804)
#
# Awake: 0
# Faces: 1
# (0.325, 0.2883505980845719, 0.07703712157713453)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.24961508830135312, 0.24961508830135312, 0.1315334104411641)
#
# Awake: 0
# Faces: 1
# (0.3055555555555556, 0.2788125341864264, 0.6859943405700354)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.23876258663828212, 0.7296939394873254)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2716072381275556, 0.2616552506059644, 0.07442084075352508)
#
# Awake: 0
# Faces: 1
# (0.3960588690528463, 0.3329560459081458, 0.08557468580776942)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2139062186164015, 0.18744537337827957, 0.0)
#
# Awake: 0
# Faces: 1
# (0.14638319883033768, 0.14269544824634822, 0.030247530200945175)
#
# Awake: 0
# Faces: 1
# (0.07490642541583835, 0.11124853987249621, 0.027735009811261455)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3157894736842105, 0.26279416561381835, 0.6213018777588136)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.13139708280690918, 0.127240226919466, 0.027735009811261455)
#
# Awake: 0
# Faces: 1
# (0.2027495562272223, 0.19172061278384314, 0.46138681426591444)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.21619434208168672, 0.18822047815984408, 0.02364257795702247)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.18428853505018536, 0.1810714920850371, 0.0)
#
# Awake: 0
# Faces: 1
# (0.20744980245361244, 0.2352794372544048, 0.04025848411142373)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.30952380952380953, 0.3178536264305499, 0.0)
#
# Awake: 0
# Faces: 1
# (0.11744404390294069, 0.14251955000862054, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.16007543486369627, 0.15635888319976896, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3, 0.30917347120042116, 0.06060606060606061)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.2619047619047619, 0.19546750924338122)
#
# Awake: 0
# Faces: 1
# (0.19253606842154392, 0.18733745120481599, 0.05547001962252292)
#
# Awake: 0
# Faces: 1
# (0.1284246743274133, 0.12373686681784413, 0.031189143077590267)
#
# Awake: 0
# Faces: 1
# (0.20505541290529222, 0.2352794372544048, 0.042835293687811936)
#
# Awake: 0
# Faces: 1
# (0.18474223348429158, 0.2, 0.028524895269256473)
#
# Awake: 0
# Faces: 1
# (0.2518868125783982, 0.23608834134288123, 0.1724137931034483)
#
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.3287979746107146, 0.9132153437995573)
#
# Awake: 0
# Faces: 1
# (0.1386750490563073, 0.14990819011352824, 0.11764705882352941)
#
# Awake: 0
# Faces: 1
# (0.16194106159846225, 0.14269544824634822, 0.0)
#
# Awake: 0
# Faces: 1
# (0.25, 0.28154625318573645, 0.11106826896141314)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.22594479646818832, 0.0)
#
# Awake: 0
# Faces: 1
# (0.11694886282802262, 0.14285714285714285, 0.04038961958610097)
#
# Awake: 0
# Faces: 1
# (0.19444444444444445, 0.21196102814697101, 0.07892004626469847)
#
# Awake: 0
# Faces: 1
# (0.13085598064755344, 0.15329238620669328, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1234661995811987, 0.17807764064044151, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.14792510968188685, 0.14285714285714285, 0.027681826617913324)
#
# Awake: 0
# Faces: 1
# (0.24211709905575113, 0.22594479646818832, 0.0)
#
# Awake: 0
# Faces: 1
# (0.29851115706299675, 0.2873592025525141, 0.09031393497987869)
#
# Awake: 0
# Faces: 1
# (0.1701274315273322, 0.182134582144651, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.3, 0.05714285714285714)
#
# Awake: 0
# Faces: 1
# (0.24961508830135312, 0.2777777777777778, 0.023749016662636548)
#
# Awake: 0
# Faces: 1
# (0.1972574607881179, 0.20631521493623017, 0.0)
#
# Awake: 0
# Faces: 1
# (0.16666666666666666, 0.22257172310433238, 0.0)
#
# Awake: 0
# Faces: 1
# (0.14482111159087308, 0.1498128508316767, 0.02855977389887699)
#
# Awake: 0
# Faces: 1
# (0.32596360383230055, 0.3310656539720239, 0.8612800233887492)
#
# Awake: 0
# Faces: 1
# (0.13339263212805205, 0.11744404390294069, 0.05502734850987509)
#
# Awake: 0
# Faces: 1
# (0.2093695690360855, 0.25216048398934465, 0.4126353527182058)
#
# Awake: 0
# Faces: 1
# (0.325, 0.3329560459081458, 0.06573827785585624)
#
# Awake: 0
# Faces: 1
# (0.2857142857142857, 0.28539089649269644, 0.12494259471568668)
#
# Awake: 0
# Faces: 1
# (0.18744537337827957, 0.17785546009148928, 0.028524895269256473)
#
# Awake: 0
# Faces: 1
# (0.22703830459324992, 0.19706114243968853, 0.036898108190245485)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.25216048398934465, 0.24315445213123463)
#
# Awake: 0
# Faces: 1
# (0.20588235294117646, 0.23256383753421428, 0.32156615482569384)
#
# Awake: 0
# Faces: 1
# (0.31846487764924103, 0.2616552506059644, 0.02480694691784169)
#
# Awake: 0
# Faces: 1
# (0.18927285376081912, 0.19174124721184263, 0.2849881999516386)
#
# Awake: 0
# Faces: 1
# (0.1386750490563073, 0.15329238620669328, 0.029361010975735173)
#
# Awake: 0
# Faces: 1
# (0.2873592025525141, 0.2873592025525141, 0.05555555555555555)
#
# Awake: 0
# Faces: 1
# (0.09889004066230124, 0.1429029965873958, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.2777777777777778, 0.30637894071415156, 0.03446227583977888)
#
# Awake: 0
# Faces: 1
# (0.10511766624552735, 0.1523525098652176, 0.0)
#
# Awake: 0
# Faces: 1
# (0.35233213170882205, 0.3312945782245396, 0.7312400184272486)
#
# Awake: 0
# Faces: 1
# (0.3128430032178382, 0.28052510760370775, 0.03508232077228118)
#
# Awake: 0
# Faces: 1
# (0.18864566947613626, 0.1800020524176937, 0.04254356298115171)
#
# Awake: 0
# Faces: 1
# (0.31838634237934677, 0.30056995195306196, 0.6878740667500971)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2, 0.20517995263032207, 0.07138306102482497)
#
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.29196900801171394, 0.5599227745979918)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.4318130187620133, 0.37496694869305336, 0.0258803470681335)
#
# Awake: 0
# Faces: 1
# (0.23974989306909258, 0.19975046777556893, 0.7647058823529411)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.2487592975524973, 0.84375)
#
# Awake: 0
# Faces: 1
# (0.15106122418594556, 0.1515696910399963, 0.0)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.23782574707724702, 0.7581815759513214)
#
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.2894736842105263, 0.02857142857142857)
#
# Awake: 0
# Faces: 1
# (0.2788125341864264, 0.23684210526315788, 0.0926482109224159)
#
# Awake: 0
# Faces: 1
# (0.3, 0.29851115706299675, 0.5184192575541551)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2683694480838308, 0.2635571302995101, 0.7586206896551724)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.30830609759979954, 0.29124853318458105, 0.03624997167972069)
#
# Awake: 0
# Faces: 1
# (0.16580886821007096, 0.17117437944912167, 0.026987629007500225)
#
# Awake: 0
# Faces: 1
# (0.24968808471946113, 0.2630719922860368, 0.8240544544777588)
#
# Awake: 0
# Faces: 1
# (0.09987523388778446, 0.11351915229662496, 0.030289126640769135)
#
# Awake: 0
# Faces: 1
# (0.12253577034896797, 0.1386750490563073, 0.2053275018925108)
#
# Awake: 0
# Faces: 1
# (0.22188007849009164, 0.2978879006693419, 0.28539089649269644)
#
# Awake: 0
# Faces: 1
# (0.2222222222222222, 0.24211709905575113, 0.3413618943659195)
#
# Awake: 0
# Faces: 1
# (0.3328201177351375, 0.26279416561381835, 0.029361010975735173)
#
# Awake: 0
# Faces: 1
# (0.15789473684210525, 0.17326517226861535, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3, 0.23936971912903793, 0.794318633557245)
#
# Awake: 0
# Faces: 1
# (0.3553753685381829, 0.3523649724724399, 0.2816852104027235)
#
# Awake: 0
# Faces: 1
# (0.3553753685381829, 0.3276399009264621, 0.49756162187971004)
#
# Awake: 0
# Faces: 1
# (0.25216048398934465, 0.2496821881329554, 0.8709677419354839)
#
# Awake: 0
# Faces: 1
# (0.2222222222222222, 0.22360679774997896, 0.09074259060283552)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.23936971912903793, 0.9091784778508321)
#
# Awake: 0
# Faces: 1
# (0.2647058823529412, 0.23971772826690166, 0.08789381029635715)
#
# Awake: 0
# Faces: 1
# (0.2222222222222222, 0.2628928070266437, 0.3332388912480454)
#
# Awake: 0
# Faces: 1
# (0.22471927624751503, 0.2512225000170304, 0.8661855860486004)
#
# Awake: 0
# Faces: 1
# (0.3547621232692877, 0.3584654851895835, 0.29598452257987684)
#
# Awake: 0
# Faces: 1
# (0.2102353324910547, 0.27607881518711636, 0.3332388912480454)
#
# Awake: 0
# Faces: 1
# (0.22188007849009164, 0.23714383857290564, 0.060357164028345685)
#
# Awake: 0
# Faces: 1
# (0.2487592975524973, 0.22703830459324992, 0.8231734448529966)
#
# Awake: 0
# Faces: 1
# (0.2222222222222222, 0.22360679774997896, 0.06748136084824301)
#
# Awake: 0
# Faces: 1
# (0.15, 0.17033740353042218, 0.029361010975735173)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.2890735821752002, 0.041522739926869986)
#
# Awake: 0
# Faces: 1
# (0.23529411764705882, 0.20921236430954301, 0.34105787599386717)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3, 0.2487592975524973, 0.8183671368293095)
#
# Awake: 0
# Faces: 1
# (0.2657636714103364, 0.2788125341864264, 0.3094361133017564)
#
# Awake: 0
# Faces: 1
# (0.16439898730535732, 0.16641005886756874, 0.1605403247669839)
#
# Awake: 0
# Faces: 1
# (0.10511766624552735, 0.1185113657849943, 0.030247530200945175)
#
# Awake: 0
# Faces: 1
# (0.29411764705882354, 0.2916757572206104, 0.037164707312358325)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2631578947368421, 0.2744055969546628, 0.766241095350685)
#
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.26357662784478947, 0.7355640360749094)
#
# Awake: 0
# Faces: 1
# (0.1608245494994372, 0.17541160386140586, 0.026987629007500225)
#
# Awake: 0
# Faces: 1
# (0.28788315742461756, 0.26160832178497173, 0.7581815759513214)
#
# Awake: 0
# Faces: 1
# (0.125, 0.11900154494317704, 0.03525631971083365)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.275, 0.28479344402135326, 0.8335367861149748)
#
# Awake: 0
# Faces: 1
# (0.2949955097939174, 0.23684210526315788, 0.09002070714423868)
#
# Awake: 0
# Faces: 1
# (0.30785451473050607, 0.31752794974596293, 0.02857142857142857)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.29702998569390543, 0.3499678201452676, 0.6499259449780869)
#
# Awake: 0
# Faces: 1
# (0.1414213562373095, 0.11744404390294069, 0.04254356298115171)
#
# Awake: 0
# Faces: 1
# (0.2668948795168779, 0.21858532913759207, 0.7496340570653092)
#
# Awake: 0
# Faces: 1
# (0.23974989306909258, 0.23782574707724702, 0.7884613231065265)
#
# Awake: 0
# Faces: 1
# (0.4750341749569001, 0.3794593943603135, 0.0776410412044005)
#
# Awake: 0
# Faces: 1
# (0.3162203479667375, 0.29851115706299675, 0.7410956739365445)
#
# Awake: 0
# Faces: 1
# (0.43314808182420994, 0.3608191628023611, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2, 0.18864566947613626, 0.10897928500669324)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1452223967283886, 0.1342888668771922, 0.0)
#
# Awake: 0
# Faces: 1
# (0.30738052751370193, 0.3419175385318709, 0.14774337103062354)
#
# Awake: 0
# Faces: 1
# (0.1810714920850371, 0.1800020524176937, 0.028467047115478598)
#
# Awake: 0
# Faces: 1
# (0.3605551275463989, 0.3599576753109892, 0.036898108190245485)
#
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.30637894071415156, 0.7686624420240878)
#
# Awake: 0
# Faces: 1
# (0.2643274401820359, 0.22771546686612018, 0.2141491830744749)
#
# Awake: 0
# Faces: 1
# (0.2962093620080057, 0.3137083812010913, 0.052342392259021375)
#
# Awake: 0
# Faces: 1
# (0.1875, 0.1975526914462439, 0.3551104121142175)
#
# Awake: 0
# Faces: 2
# (0.3632763273458409, 0.2366483149731612, 0.24211709905575113)
#
# Awake: 0
# Faces: 1
# (0.1355815361366601, 0.14499607298433959, 0.041576537496303176)
#
# Awake: 0
# Faces: 1
# (0.2638752983404338, 0.2630719922860368, 0.04998438232040614)
#
# Awake: 0
# Faces: 1
# (0.11094003924504582, 0.15329238620669328, 0.041576537496303176)
#
# Awake: 0
# Faces: 1
# (0.2873592025525141, 0.3178536264305499, 0.12878418324335694)
#
# Awake: 0
# Faces: 1
# (0.22633936510629632, 0.22086305214969307, 0.026090902514277467)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.19900743804199783, 0.23782574707724702, 0.5151515151515151)
#
# Awake: 0
# Faces: 1
# (0.14046382134987784, 0.11744404390294069, 0.02739983121755955)
#
# Awake: 0
# Faces: 1
# (0.2857142857142857, 0.30917347120042116, 0.06763553368079128)
#
# Awake: 0
# Faces: 1
# (0.21832400154313186, 0.2110154611626203, 0.0)
#
# Awake: 0
# Faces: 1
# (0.282842712474619, 0.26279416561381835, 0.03363363969981562)
#
# Awake: 0
# Faces: 1
# (0.2996257016633534, 0.2996257016633534, 0.05714285714285714)
#
# Awake: 0
# Faces: 1
# (0.1656472891122698, 0.14269544824634822, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.3553753685381829, 0.3842274868670723, 0.9121817098024457)
#
# Awake: 0
# Faces: 1
# (0.1701274315273322, 0.14269544824634822, 0.027767067240353285)
#
# Awake: 0
# Faces: 1
# (0.2139062186164015, 0.22257172310433238, 0.0)
#
# Awake: 0
# Faces: 1
# (0.15245942257232578, 0.15789473684210525, 0.03914801463431357)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.13803940759355818, 0.2, 0.0)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.27363522730774703, 0.12121539504758783)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.2388450959634127, 0.035623524993954825)
#
# Awake: 0
# Faces: 1
# (0.26424909878161656, 0.22870874995874624, 0.11139460994180819)
#
# Awake: 0
# Faces: 1
# (0.16127417724876889, 0.14285714285714285, 0.041576537496303176)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1701274315273322, 0.15329238620669328, 0.028524895269256473)
#
# Awake: 0
# Faces: 1
# (0.19824558013652693, 0.17848558013543783, 0.09375)
#
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.3499678201452676, 0.8382736442849094)
#
# Awake: 0
# Faces: 1
# (0.22209280215830052, 0.2110154611626203, 0.2)
#
# Awake: 0
# Faces: 1
# (0.07844645405527362, 0.10468478451804275, 0.027777777777777776)
#
# Awake: 0
# Faces: 1
# (0.2523613954823553, 0.2484709336684047, 0.08320502943378437)
#
# Awake: 0
# Faces: 1
# (0.17460757394239454, 0.1498128508316767, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.29545454545454547, 0.3197969957242153, 0.06060606060606061)
#
# Awake: 0
# Faces: 1
# (0.16330847331422962, 0.13803940759355818, 0.029361010975735173)
#
# Awake: 0
# Faces: 1
# (0.1608245494994372, 0.19174124721184263, 0.030289126640769135)
#
# Awake: 0
# Faces: 1
# (0.1738690057052985, 0.1800020524176937, 0.06049506040189035)
#
# Awake: 0
# Faces: 1
# (0.1896181852559909, 0.2002917589880262, 0.05286641147524035)
#
# Awake: 0
# Faces: 1
# (0.24961508830135312, 0.2619047619047619, 0.19523741203679054)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.22376876883610253, 0.24087440257466058, 0.041522739926869986)
#
# Awake: 0
# Faces: 1
# (0.09302605094190634, 0.13063248606829103, 0.030247530200945175)
#
# Awake: 0
# Faces: 1
# (0.3181818181818182, 0.3178536264305499, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.23850259343081628, 0.22257172310433238, 0.13303802104754786)
#
# Awake: 0
# Faces: 1
# (0.22360679774997896, 0.19066719485096545, 0.09457031182808988)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.19325517063098144, 0.18848099105706262, 0.44943855249503006)
#
# Awake: 0
# Faces: 1
# (0.10590169943749475, 0.15636456680019054, 0.041522739926869986)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.16236357547006, 0.11043152607484653, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.21029171299146662, 0.20113399857238304, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2949955097939174, 0.24008172698993846, 0.5903007401651968)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.07894736842105263, 0.10537612944674757, 0.0)
#
# Awake: 0
# Faces: 1
# (0.17329174830334546, 0.1498128508316767, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.34022554968363894, 0.3108636467454263, 0.06049506040189035)
#
# Awake: 0
# Faces: 1
# (0.2927452769221792, 0.2928931088450006, 0.025342864042323516)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.23876258663828212, 0.20795009796401456, 0.7568230077691596)
#
# Awake: 0
# Faces: 1
# (0.30830609759979954, 0.2938507082299913, 0.6545245349594659)
#
# Awake: 0
# Faces: 1
# (0.22529441422441898, 0.22188007849009164, 0.10526315789473684)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.3162203479667375, 0.6768469748851417)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.26424909878161656, 0.07894736842105263)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.27363522730774703, 0.699611434885408)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1234661995811987, 0.11124853987249621, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2523613954823553, 0.2777777777777778, 0.175)
#
# Awake: 0
# Faces: 1
# (0.31796743500784785, 0.31405435355412825, 0.7329262651180465)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.19096534121710312, 0.16194106159846225, 0.0)
#
# Awake: 0
# Faces: 1
# (0.28539089649269644, 0.2743249919681754, 0.0)
#
# Awake: 0
# Faces: 1
# (0.15768735977629134, 0.1688453678043514, 0.027777777777777776)
#
# Awake: 0
# Faces: 1
# (0.2027495562272223, 0.2336824951347944, 0.7772448707074855)
#
# Awake: 0
# Faces: 1
# (0.11043152607484653, 0.13025205920199728, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.3078314151048782, 0.6892455167955777)
#
# Awake: 0
# Faces: 1
# (0.305085107923876, 0.2617119612951069, 0.585858689276241)
#
# Awake: 0
# Faces: 1
# (0.2139062186164015, 0.20744980245361244, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3505237427021916, 0.2773500981126146, 0.7411579241249133)
#
# Awake: 0
# Faces: 1
# (0.31796743500784785, 0.31535299873658207, 0.0425435629811517)
#
# Awake: 0
# Faces: 1
# (0.21832400154313186, 0.24087440257466058, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2996257016633534, 0.29514979597122487, 0.03508232077228118)
#
# Awake: 0
# Faces: 1
# (0.31752794974596293, 0.2900491518372268, 0.36489680541794833)
#
# Awake: 0
# Faces: 1
# (0.2534196007116017, 0.23911692409784674, 0.06872892814876451)
#
# Awake: 0
# Faces: 1
# (0.23938794927456072, 0.23876258663828212, 0.03423934786989504)
#
# Awake: 0
# Faces: 1
# (0.1800020524176937, 0.1875, 0.40500265347435316)
#
# Awake: 0
# Faces: 1
# (0.11694886282802262, 0.09950371902099892, 0.027767067240353285)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.2760984297722801, 0.08789381029635715)
#
# Awake: 0
# Faces: 1
# (0.3820018448736402, 0.3695652173913043, 0.04993761694389223)
#
# Awake: 0
# Faces: 1
# (0.3055555555555556, 0.3162203479667375, 0.632981774420131)
#
# Awake: 0
# Faces: 1
# (0.22188007849009164, 0.2111500763274038, 0.02855977389887699)
#
# Awake: 0
# Faces: 1
# (0.18093070201573147, 0.15594571538795132, 0.3953488372093023)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.23971772826690166, 0.8275862068965517)
#
# Awake: 0
# Faces: 1
# (0.23974989306909258, 0.23651474905243652, 0.030028540676910215)
#
# Awake: 0
# Faces: 1
# (0.25, 0.25460333819405395, 0.28261670947211076)
#
# Awake: 0
# Faces: 1
# (0.06318285663939095, 0.08493173674701406, 0.0)
#
# Awake: 0
# Faces: 1
# (0.20113399857238304, 0.17707591868692504, 0.7324646235681017)
#
# Awake: 0
# Faces: 1
# (0.1460515594592465, 0.19257117688026187, 0.3022438607339301)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.21807667071701348, 0.19066719485096545, 0.03433002159959814)
#
# Awake: 0
# Faces: 1
# (0.29942473580817114, 0.30411126135284217, 0.06859943405700354)
#
# Awake: 0
# Faces: 1
# (0.2530294240356804, 0.21347047650771073, 0.03006244442563018)
#
# Awake: 0
# Faces: 1
# (0.29411764705882354, 0.2773500981126146, 0.11538461538461539)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.17091083136448731, 0.14680505487867587, 0.40430377003131995)
#
# Awake: 0
# Faces: 1
# (0.2530294240356804, 0.2668948795168779, 0.06057825328153827)
#
# Awake: 0
# Faces: 1
# (0.38052119532359524, 0.34884994609834646, 0.1315334104411641)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.27607881518711636, 0.2617119612951069, 0.7082050579776155)
#
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.18093070201573147, 0.3579356280564978)
#
# Awake: 0
# Faces: 1
# (0.07851358838853206, 0.12437964877624864, 0.02855977389887699)
#
# Awake: 0
# Faces: 1
# (0.24949920596716638, 0.23850259343081628, 0.7480940248730513)
#
# Awake: 0
# Faces: 1
# (0.18569533817705186, 0.1412811624583021, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2650336523863296, 0.30952380952380953, 0.05165355406757764)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.29668090586048923, 0.6333333333333333)
#
# Awake: 0
# Faces: 1
# (0.2894736842105263, 0.2719574970387818, 0.3233895676208201)
#
# Awake: 0
# Faces: 1
# (0.28539089649269644, 0.3114943459594814, 0.02220030681036019)
#
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.19665385615732067, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2894736842105263, 0.3351155373249634, 0.1303116728289208)
#
# Awake: 0
# Faces: 1
# (0.2949955097939174, 0.2800964052936168, 0.6781390797358372)
#
# Awake: 0
# Faces: 1
# (0.1482693836184332, 0.1629061226915836, 0.20987329445336178)
#
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.22376876883610253, 0.035355339059327376)
#
# Awake: 0
# Faces: 1
# (0.305085107923876, 0.24968808471946113, 0.585858689276241)
#
# Awake: 0
# Faces: 1
# (0.2557757312166826, 0.2222222222222222, 0.15784009252939693)
#
# Awake: 0
# Faces: 1
# (0.3055555555555556, 0.30262874684312724, 0.6880209161537814)
#
# Awake: 0
# Faces: 1
# (0.2900491518372268, 0.24968808471946113, 0.766241095350685)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3020690632574555, 0.2877458354722394, 0.023802777946288958)
#
# Awake: 0
# Faces: 1
# (0.22188007849009164, 0.2650854018430103, 0.7649686210234002)
#
# Awake: 0
# Faces: 1
# (0.2523613954823553, 0.2530294240356804, 0.07894736842105263)
#
# Awake: 0
# Faces: 1
# (0.29651742278276144, 0.2788125341864264, 0.6536198703460924)
#
# Awake: 0
# Faces: 1
# (0.2499373493131839, 0.2312295731998497, 0.0258803470681335)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.19108411851099838, 0.24571804673358047, 0.09640373590996239)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.07883824968414552, 0.10040444031431572, 0.029399051601892736)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3131864367181832, 0.34217096844158384, 0.030247530200945175)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.33000782690058567, 0.401534800126906)
#
# Awake: 0
# Faces: 1
# (0.2508465434731549, 0.23089088604787955, 0.049446817643414874)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.35233213170882205, 0.32387162103263195, 0.1419332389509149)
#
# Awake: 0
# Faces: 1
# (0.31846487764924103, 0.2823419577959951, 0.026783579200279007)
#
# Awake: 0
# Faces: 1
# (0.1386750490563073, 0.1507917405258444, 0.02631578947368421)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.07883824968414552, 0.10537612944674757, 0.0)
#
# Awake: 0
# Faces: 1
# (0.17848558013543783, 0.2023717579385011, 0.5388945710790767)
#
# Awake: 0
# Faces: 1
# (0.17149858514250885, 0.14655482882269746, 0.0)
#
# Awake: 0
# Faces: 1
# (0.13157894736842105, 0.1351029811192582, 0.028524895269256473)
#
# Awake: 0
# Faces: 1
# (0.3235294117647059, 0.26539634065922857, 0.6401843996644799)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1972574607881179, 0.22257172310433238, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1972574607881179, 0.19179881852291683, 0.03834824944236852)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.14448340845183177, 0.16194106159846225, 0.14051285846430578)
#
# Awake: 0
# Faces: 1
# (0.25216048398934465, 0.2873592025525141, 0.17005886649925459)
#
# Awake: 0
# Faces: 1
# (0.16580886821007096, 0.1764254961895988, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.16330847331422962, 0.15768735977629134, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.30952380952380953, 0.2970697229969426, 0.13293426071377412)
#
# Awake: 0
# Faces: 1
# (0.2873592025525141, 0.3181818181818182, 0.029411764705882353)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.19773531304604383, 0.14111656847732632)
#
# Awake: 0
# Faces: 1
# (0.1800020524176937, 0.1810714920850371, 0.06662966046527696)
#
# Awake: 0
# Faces: 1
# (0.15594571538795132, 0.14251955000862054, 0.041522739926869986)
#
# Awake: 0
# Faces: 1
# (0.20744980245361244, 0.18318582636182795, 0.029361010975735173)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.14903688676179663, 0.15329238620669328, 0.029361010975735173)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.17541160386140586, 0.17329174830334546, 0.0)
#
# Awake: 0
# Faces: 1
# (0.16194106159846225, 0.14269544824634822, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.2777777777777778, 0.23974989306909258, 0.061267885174483984)
#
# Awake: 0
# Faces: 1
# (0.2647058823529412, 0.22529441422441898, 0.11139460994180819)
#
# Awake: 0
# Faces: 1
# (0.14455674434673424, 0.15732919388188818, 0.041522739926869986)
#
# Awake: 0
# Faces: 1
# (0.14251955000862054, 0.12484404235973057, 0.0)
#
# Awake: 0
# Faces: 1
# (0.22564182293382393, 0.22426173767603233, 0.11107078771616638)
#
# Awake: 0
# Faces: 1
# (0.19611613513818402, 0.2110154611626203, 0.13325932093055393)
#
# Awake: 0
# Faces: 1
# (0.25335270359176765, 0.22766042320237156, 0.058823529411764705)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.20744980245361244, 0.0)
#
# Awake: 0
# Faces: 1
# (0.17460757394239454, 0.14655482882269746, 0.0)
#
# Awake: 0
# Faces: 1
# (0.32297112073308687, 0.3310656539720239, 0.7818700369735249)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.3, 0.02857142857142857)
#
# Awake: 0
# Faces: 1
# (0.18569533817705186, 0.22360679774997896, 0.033259505261886965)
#
# Awake: 0
# Faces: 1
# (0.26715641180702626, 0.26424365957257945, 0.034401045807689073)
#
# Awake: 0
# Faces: 1
# (0.2719574970387818, 0.3016921834310232, 0.06576670522058205)
#
# Awake: 0
# Faces: 1
# (0.15702717677706413, 0.175, 0.0)
#
# Awake: 0
# Faces: 1
# (0.11086296585708666, 0.09950371902099892, 0.02855977389887699)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.28539089649269644, 0.29676330752293384, 0.1288470508005519)
#
# Awake: 0
# Faces: 1
# (0.12373686681784413, 0.15232313442166484, 0.030178582014172842)
#
# Awake: 0
# Faces: 1
# (0.3114943459594814, 0.3333333333333333, 0.09086737992230741)
#
# Awake: 0
# Faces: 1
# (0.23651474905243652, 0.21428571428571427, 0.48361941016437077)
#
# Awake: 0
# Faces: 1
# (0.34566186625242745, 0.31407645648142984, 0.8455286862264967)
#
# Awake: 0
# Faces: 1
# (0.2616812706568056, 0.21982421091879367, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2805283198220218, 0.31622776601683794, 0.052342392259021375)
#
# Awake: 0
# Faces: 1
# (0.10511766624552735, 0.15732919388188818, 0.0)
#
# Awake: 0
# Faces: 1
# (0.15767649936829103, 0.13636363636363635, 0.0)
#
# Awake: 0
# Faces: 1
# (0.11752512368056713, 0.13025205920199728, 0.0)
#
# Awake: 0
# Faces: 1
# (0.13010979365773964, 0.1029986523640147, 0.0)
#
# Awake: 0
# Faces: 1
# (0.22216356051417732, 0.23608834134288123, 0.4220215513229412)
#
# Awake: 0
# Faces: 1
# (0.3827621310863653, 0.3343402696845619, 0.05852057359806529)
#
# Awake: 0
# Faces: 1
# (0.26430342040599236, 0.20513217183267982, 0.7496340570653092)
#
# Awake: 0
# Faces: 1
# (0.16101915080209417, 0.15373624935706678, 0.04254356298115171)
#
# Awake: 0
# Faces: 2
# (0.23333333333333334, 0.305957338282927, 0.1414213562373095)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2102353324910547, 0.200830861284057, 0.766241095350685)
#
# Awake: 0
# Faces: 1
# (0.12475657231036107, 0.1815452033828341, 0.036155076303109365)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.25993762245501817, 0.19900743804199783, 0.6868696261070818)
#
# Awake: 0
# Faces: 1
# (0.18318582636182795, 0.15789473684210525, 0.0)
#
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.1656472891122698, 0.042835293687811936)
#
# Awake: 0
# Faces: 1
# (0.24968808471946113, 0.2487592975524973, 0.7358821178351062)
#
# Awake: 0
# Faces: 1
# (0.2617119612951069, 0.2639632607645147, 0.6947631327039907)
#
# Awake: 0
# Faces: 1
# (0.25, 0.2403700850309326, 0.7329262651180465)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2777777777777778, 0.2773500981126146, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3078314151048782, 0.2916757572206104, 0.04159451654038515)
#
# Awake: 0
# Faces: 1
# (0.275, 0.30056995195306196, 0.8333333333333334)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.2873592025525141, 0.7575757575757576)
#
# Awake: 0
# Faces: 1
# (0.12953194003770996, 0.1540019993382291, 0.13503919442718335)
#
# Awake: 0
# Faces: 1
# (0.21065522529907, 0.1975526914462439, 0.0926482109224159)
#
# Awake: 0
# Faces: 1
# (0.19786404515604614, 0.23971772826690166, 0.12445427825741102)
#
# Awake: 0
# Faces: 1
# (0.252750542044244, 0.2978879006693419, 0.3340879089075014)
#
# Awake: 0
# Faces: 1
# (0.35294117647058826, 0.34829796928755713, 0.393591831615609)
#
# Awake: 0
# Faces: 1
# (0.24968808471946113, 0.22940893715712163, 0.8433383141984728)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.275, 0.2370227315699886, 0.8486362508392699)
#
# Awake: 0
# Faces: 1
# (0.3288759424673825, 0.32147446870545965, 0.36760731104690386)
#
# Awake: 0
# Faces: 1
# (0.20588235294117646, 0.18474223348429158, 0.30917347120042116)
#
# Awake: 0
# Faces: 1
# (0.31405435355412825, 0.3245945101352995, 0.057049790538512946)
#
# Awake: 0
# Faces: 1
# (0.15, 0.14269544824634822, 0.042776467438466456)
#
# Awake: 0
# Faces: 1
# (0.3547621232692877, 0.3604127312396988, 0.36316923312953137)
#
# Awake: 0
# Faces: 1
# (0.275, 0.23936971912903793, 0.7880995606084251)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1941450686788302, 0.1664780229540729, 0.031113569564352756)
#
# Awake: 0
# Faces: 1
# (0.2222222222222222, 0.22086305214969307, 0.31669659913716236)
#
# Awake: 0
# Faces: 1
# (0.22564182293382393, 0.2693811516220012, 0.31669659913716236)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.23971772826690166, 0.06222713912870551)
#
# Awake: 0
# Faces: 1
# (0.31535299873658207, 0.2996257016633534, 0.06974104408145883)
#
# Awake: 0
# Faces: 1
# (0.225, 0.2536857024815635, 0.865386506313644)
#
# Awake: 0
# Faces: 1
# (0.3328201177351375, 0.29264061094811233, 0.49785047965762663)
#
# Awake: 0
# Faces: 1
# (0.14791375932615672, 0.16641005886756874, 0.13810200921222546)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3333333333333333, 0.30262874684312724, 0.5390716933750933)
#
# Awake: 0
# Faces: 1
# (0.30785451473050607, 0.305085107923876, 0.02857142857142857)
#
# Awake: 0
# Faces: 1
# (0.2996257016633534, 0.26160832178497173, 0.6966499127376901)
#
# Awake: 0
# Faces: 1
# (0.31752794974596293, 0.28539089649269644, 0.6868696261070818)
#
# Awake: 0
# Faces: 1
# (0.2617119612951069, 0.26072500472698745, 0.6973080611251327)
#
# Awake: 0
# Faces: 1
# (0.18093070201573147, 0.19066719485096545, 0.0)
#
# Awake: 0
# Faces: 1
# (0.16580886821007096, 0.17117437944912167, 0.0)
#
# Awake: 0
# Faces: 1
# (0.29702998569390543, 0.29124853318458105, 0.037164707312358325)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.294257422207658, 0.2635571302995101, 0.766241095350685)
#
# Awake: 0
# Faces: 1
# (0.23876258663828212, 0.2512225000170304, 0.056934094230957195)
#
# Awake: 0
# Faces: 1
# (0.21832400154313186, 0.2326803115618832, 0.11493493650809093)
#
# Awake: 0
# Faces: 1
# (0.16666666666666666, 0.14834045293024462, 0.8)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.288082694235928, 0.24968808471946113, 0.7567929638407975)
#
# Awake: 0
# Faces: 2
# (0.21952205224669774, 0.30804303424830937, 0.1464157737903536)
#
# Awake: 0
# Faces: 1
# (0.18864566947613626, 0.11748738691712715, 0.04254356298115171)
#
# Awake: 0
# Faces: 1
# (0.2788125341864264, 0.24135404574916758, 0.8060323502739513)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1313548918227579, 0.14499607298433959, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.11094003924504582, 0.12437964877624864, 0.029361010975735173)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.21832400154313186, 0.25, 0.3834824944236852)
#
# Awake: 0
# Faces: 1
# (0.36170385327085214, 0.31222908534136, 0.036898108190245485)
#
# Awake: 0
# Faces: 1
# (0.3235294117647059, 0.3310656539720239, 0.8455286862264967)
#
# Awake: 0
# Faces: 1
# (0.1747816593036228, 0.16277903773109956, 0.0)
#
# Awake: 0
# Faces: 1
# (0.1452223967283886, 0.15329238620669328, 0.0)
#
# Awake: 0
# Faces: 1
# (0.12403473458920847, 0.1261886162812672, 0.030289126640769135)
#
# Awake: 0
# Faces: 1
# (0.30952380952380953, 0.3181818181818182, 0.06237828615518053)
#
# Awake: 0
# Faces: 1
# (0.23651474905243652, 0.2028242685634354, 0.5319086662842529)
#
# Awake: 0
# Faces: 1
# (0.1831983729065748, 0.17785546009148928, 0.04958034310906081)
#
# Awake: 0
# Faces: 1
# (0.1313548918227579, 0.16903751472779344, 0.033167906340332974)
#
# Awake: 0
# Faces: 1
# (0.2996257016633534, 0.33464622145315104, 0.12493900951088485)
#
# Awake: 0
# Faces: 1
# (0.31838634237934677, 0.2996257016633534, 0.06386159585991316)
#
# Awake: 0
# Faces: 1
# (0.2571922625628131, 0.26424365957257945, 0.0)
#
# Awake: 0
# Faces: 1
# (0.13545709229571928, 0.1538647306476965, 0.027607881518711633)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1234661995811987, 0.1523525098652176, 0.0)
#
# Awake: 0
# Faces: 1
# (0.17460757394239454, 0.175, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3768510093300177, 0.3499678201452676, 0.9121817098024457)
#
# Awake: 0
# Faces: 1
# (0.11606754760960308, 0.175, 0.02855977389887699)
#
# Awake: 0
# Faces: 1
# (0.21875, 0.22257172310433238, 0.0)
#
# Awake: 0
# Faces: 1
# (0.13948208816291766, 0.12373686681784413, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3055555555555556, 0.3157894736842105, 0.05714285714285714)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.2484709336684047, 0.11386818846191439)
#
# Awake: 0
# Faces: 1
# (0.16127417724876889, 0.14269544824634822, 0.0)
#
# Awake: 0
# Faces: 1
# (0.19824558013652693, 0.17848558013543783, 0.02857142857142857)
#
# Awake: 0
# Faces: 1
# (0.24571804673358047, 0.26402867467729757, 0.14276612204964995)
#
# Awake: 0
# Faces: 1
# (0.24253562503633297, 0.22594479646818832, 0.0)
#
# Awake: 0
# Faces: 1
# (0.07486158461265358, 0.1000170980890904, 0.09565108902971729)
#
# Awake: 0
# Faces: 1
# (0.13139708280690918, 0.1771938751820891, 0.0)
#
# Awake: 0
# Faces: 1
# (0.13085598064755344, 0.15732919388188818, 0.0)
#
# Awake: 0
# Faces: 1
# (0.25, 0.22766042320237156, 0.0881971548056782)
#
# Awake: 0
# Faces: 1
# (0.2571922625628131, 0.1941450686788302, 0.08944271909999159)
#
# Awake: 0
# Faces: 1
# (0.12841645645144356, 0.13622298275594996, 0.0)
#
# Awake: 0
# Faces: 1
# (0.12475657231036107, 0.1800020524176937, 0.030289126640769135)
#
# Awake: 0
# Faces: 1
# (0.1752618713510958, 0.20857991671395915, 0.041576537496303176)
#
# Awake: 0
# Faces: 1
# (0.2800964052936168, 0.22529441422441898, 0.13668525332802745)
#
# Awake: 0
# Faces: 1
# (0.2857142857142857, 0.2970697229969426, 0.029411764705882353)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.21595085938862488, 0.21280831802947608, 0.0)
#
# Awake: 0
# Faces: 1
# (0.20631521493623017, 0.20505541290529222, 0.041522739926869986)
#
# Awake: 0
# Faces: 1
# (0.27465689319140724, 0.25, 0.20815272356090667)
#
# Awake: 0
# Faces: 1
# (0.31114177726023884, 0.3333333333333333, 0.1288470508005519)
#
# Awake: 0
# Faces: 1
# (0.16007543486369627, 0.14251955000862054, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1800020524176937, 0.15455418600896656, 0.045407660918649985)
#
# Awake: 0
# Faces: 1
# (0.17541160386140586, 0.19773531304604383, 0.07631586874921233)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.305085107923876, 0.34210526315789475, 0.6)
#
# Awake: 0
# Faces: 1
# (0.07894736842105263, 0.12167605132909617, 0.027767067240353285)
#
# Awake: 0
# Faces: 1
# (0.14638319883033768, 0.14672089667067573, 0.0)
#
# Awake: 0
# Faces: 1
# (0.23891487134169592, 0.22257172310433238, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.18093070201573147, 0.1752618713510958, 0.02702702702702703)
#
# Awake: 0
# Faces: 1
# (0.2512225000170304, 0.24018068605679, 0.027513674254937545)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1341870181436823, 0.14285714285714285, 0.0)
#
# Awake: 0
# Faces: 1
# (0.29651742278276144, 0.2534196007116017, 0.5952085282579794)
#
# Awake: 0
# Faces: 1
# (0.0850419784016654, 0.1342888668771922, 0.02855977389887699)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.28539089649269644, 0.3210806495339678, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.07883824968414552, 0.12410671347131458, 0.02855977389887699)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2716072381275556, 0.25979224926766525, 0.053963468304710556)
#
# Awake: 0
# Faces: 1
# (0.3235294117647059, 0.3523649724724399, 0.36270588023294514)
#
# Awake: 0
# Faces: 1
# (0.2518868125783982, 0.2767114301352826, 0.20815272356090667)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.26072500472698745, 0.23890473351968816, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2774754878398196, 0.3016921834310232, 0.0)
#
# Awake: 0
# Faces: 1
# (0.29361010975735174, 0.3087053138358001, 0.6880209161537814)
#
# Awake: 0
# Faces: 1
# (0.29651742278276144, 0.24961508830135312, 0.07894736842105263)
#
# Awake: 0
# Faces: 1
# (0.26539634065922857, 0.2668948795168779, 0.6984496104996263)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.26430342040599236, 0.7581700684751354)
#
# Awake: 0
# Faces: 1
# (0.33563229250828386, 0.2668948795168779, 0.6536198703460924)
#
# Awake: 0
# Faces: 1
# (0.22870874995874624, 0.22188007849009164, 0.10806864539165983)
#
# Awake: 0
# Faces: 1
# (0.3108636467454263, 0.31114177726023884, 0.023782574707724703)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.11748738691712715, 0.10537612944674757, 0.030178582014172842)
#
# Awake: 0
# Faces: 1
# (0.20588235294117646, 0.22426173767603233, 0.036935842757655886)
#
# Awake: 0
# Faces: 1
# (0.2996257016633534, 0.3210806495339678, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.2650854018430103, 0.2855977389887699)
#
# Awake: 0
# Faces: 1
# (0.27607881518711636, 0.2788125341864264, 0.5699763999032772)
#
# Awake: 0
# Faces: 1
# (0.2139062186164015, 0.26402867467729757, 0.034159349284257755)
#
# Awake: 0
# Faces: 1
# (0.2497803739249954, 0.2762040184244509, 0.20564575285398803)
#
# Awake: 0
# Faces: 1
# (0.292103118918493, 0.2530294240356804, 0.6781390797358372)
#
# Awake: 0
# Faces: 1
# (0.2894736842105263, 0.3157894736842105, 0.129391195403566)
#
# Awake: 0
# Faces: 1
# (0.18093070201573147, 0.16552117772047362, 0.0)
#
# Awake: 0
# Faces: 1
# (0.20631521493623017, 0.2055270768301462, 0.7503714579065254)
#
# Awake: 0
# Faces: 1
# (0.11043152607484653, 0.13025205920199728, 0.02857142857142857)
#
# Awake: 0
# Faces: 1
# (0.1460515594592465, 0.14680505487867587, 0.3665567521632638)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.2890735821752002, 0.6651901052377394)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.29124853318458105, 0.29872707773217105, 0.633857874181182)
#
# Awake: 0
# Faces: 1
# (0.2716072381275556, 0.2977229608361267, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.29411764705882354, 0.3078314151048782, 0.19216561050602196)
#
# Awake: 0
# Faces: 1
# (0.3329560459081458, 0.34884994609834646, 0.1339992578523194)
#
# Awake: 0
# Faces: 1
# (0.23850259343081628, 0.24997155432189194, 0.0)
#
# Awake: 0
# Faces: 1
# (0.18474223348429158, 0.14680505487867587, 0.3808444471406233)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.1507917405258444, 0.14705882352941177, 0.3329560459081458)
#
# Awake: 0
# Faces: 1
# (0.22766042320237156, 0.20206980493733886, 0.7589528978715665)
#
# Awake: 0
# Faces: 1
# (0.40430377003131995, 0.391304347826087, 0.0)
#
# Awake: 0
# Faces: 1
# (0.23651474905243652, 0.18395591592967286, 0.04753289820861187)
#
# Awake: 0
# Faces: 1
# (0.26715641180702626, 0.30597159483648995, 0.0710220824228435)
#
# Awake: 0
# Faces: 1
# (0.22870874995874624, 0.22870874995874624, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.29611441649441417, 0.28539089649269644, 0.04440061362072038)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.29065658392992416, 0.48361941016437077)
#
# Awake: 0
# Faces: 1
# (0.28788315742461756, 0.30262874684312724, 0.7403961969765981)
#
# Awake: 0
# Faces: 1
# (0.2336824951347944, 0.22529441422441898, 0.7781256017217237)
#
# Awake: 0
# Faces: 1
# (0.21052631578947367, 0.23651774990351246, 0.0)
#
# Awake: 0
# Faces: 1
# (0.11132139496304724, 0.1538647306476965, 0.0)
#
# Awake: 0
# Faces: 1
# (0.1386750490563073, 0.14903688676179663, 0.02701716134791496)
#
# Awake: 0
# Faces: 1
# (0.3363363969981562, 0.30952380952380953, 0.030082841879809342)
#
# Awake: 0
# Faces: 1
# (0.292103118918493, 0.2534196007116017, 0.6412234498911868)
#
# Awake: 0
# Faces: 1
# (0.25, 0.305085107923876, 0.021739130434782608)
#
# Awake: 0
# Faces: 1
# (0.23850259343081628, 0.2388450959634127, 0.0)
#
# Awake: 0
# Faces: 1
# (0.30597159483648995, 0.31838634237934677, 0.555174907648204)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.18124346059318763, 0.40464722508691225)
#
# Awake: 0
# Faces: 1
# (0.26279416561381835, 0.2650854018430103, 0.3647293831538389)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.21832400154313186, 0.23727844885472751, 0.036935842757655886)
#
# Awake: 0
# Faces: 1
# (0.2557041559783794, 0.2530294240356804, 0.033259505261886965)
#
# Awake: 0
# Faces: 1
# (0.23944788193665223, 0.22471927624751503, 0.02883749003642362)
#
# Awake: 0
# Faces: 1
# (0.252750542044244, 0.23971772826690166, 0.0)
#
# Awake: 0
# Faces: 1
# (0.12253577034896797, 0.10537612944674757, 0.02701716134791496)
#
# Awake: 0
# Faces: 1
# (0.1515696910399963, 0.16236357547006, 0.3719924439802217)
#
# Awake: 0
# Faces: 1
# (0.26539634065922857, 0.2536857024815635, 0.7403961969765981)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 2
# (0.23076923076923078, 0.31121614998065, 0.1424940999758193)
#
# Awake: 0
# Faces: 1
# (0.22529441422441898, 0.2111500763274038, 0.0)
#
# Awake: 0
# Faces: 1
# (0.22703830459324992, 0.2296482891597408, 0.15364425591947517)
#
# Awake: 0
# Faces: 1
# (0.2336824951347944, 0.25, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.22426173767603233, 0.035623524993954825)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2916757572206104, 0.2668948795168779, 0.6412234498911868)
#
# Awake: 0
# Faces: 1
# (0.23488808780588138, 0.22188007849009164, 0.10526315789473684)
#
# Awake: 0
# Faces: 1
# (0.2788125341864264, 0.2512225000170304, 0.7237077926353565)
#
# Awake: 0
# Faces: 1
# (0.2631578947368421, 0.23971772826690166, 0.7419354838709677)
#
# Awake: 0
# Faces: 1
# (0.3254011122935525, 0.2900491518372268, 0.6536198703460924)
#
# Awake: 0
# Faces: 1
# (0.23651474905243652, 0.24961508830135312, 0.10526315789473684)
#
# Awake: 0
# Faces: 1
# (0.24008172698993846, 0.22694573469258858, 0.11627906976744186)
#
# Awake: 0
# Faces: 1
# (0.3, 0.3108636467454263, 0.06974104408145883)
#
# Awake: 0
# Faces: 1
# (0.13139708280690918, 0.15329238620669328, 0.027735009811261455)
#
# Awake: 0
# Faces: 1
# (0.1800020524176937, 0.22188007849009164, 0.3952419717289855)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.15702717677706413, 0.12437964877624864, 0.022216737285146886)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.18474223348429158, 0.21435005469079302, 0.0)
#
# Awake: 0
# Faces: 1
# (0.19553847221876072, 0.1342888668771922, 0.0292103118918493)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.10511766624552735, 0.10537612944674757, 0.027767067240353285)
#
# Awake: 0
# Faces: 1
# (0.26786360440655144, 0.2800964052936168, 0.39419124842072756)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.08333333333333333, 0.1342888668771922, 0.027767067240353285)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.31114177726023884, 0.33464622145315104, 0.08693598163686228)
#
# Awake: 0
# Faces: 1
# (0.23823144500331547, 0.2614461772600697, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.35233213170882205, 0.30411126135284217, 0.2105798931586654)
#
# Awake: 0
# Faces: 1
# (0.24951314462072213, 0.2557041559783794, 0.07686624420240878)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.12403473458920847, 0.18474223348429158, 0.0)
#
# Awake: 0
# Faces: 1
# (0.35, 0.3178536264305499, 0.09370425713316365)
#
# Awake: 0
# Faces: 1
# (0.22188007849009164, 0.21347047650771073, 0.131953646049976)
#
# Awake: 0
# Faces: 1
# (0.23891487134169592, 0.22471927624751503, 0.17374889710522776)
#
# Awake: 0
# Faces: 1
# (0.18927285376081912, 0.17848558013543783, 0.06565321642986127)
#
# Awake: 0
# Faces: 1
# (0.2208706236059213, 0.2110154611626203, 0.041522739926869986)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3350254240920351, 0.3178536264305499, 0.02857142857142857)
#
# Awake: 0
# Faces: 1
# (0.24951314462072213, 0.2671116827781183, 0.09657341699694758)
#
# Awake: 0
# Faces: 1
# (0.12437523838133162, 0.15768735977629134, 0.0)
#
# Awake: 0
# Faces: 1
# (0.18474223348429158, 0.20206980493733886, 0.2446508013445698)
#
# Awake: 0
# Faces: 1
# (0.19999999999999998, 0.16620562382863344, 0.1201850425154663)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2890735821752002, 0.26539634065922857, 0.06152244594482623)
#
# Awake: 0
# Faces: 1
# (0.17954630514150904, 0.15294717870969343, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.23850259343081628, 0.2388450959634127, 0.0)
#
# Awake: 0
# Faces: 1
# (0.13760081152442907, 0.17883353911964264, 0.029399051601892736)
#
# Awake: 0
# Faces: 1
# (0.1095993248702382, 0.1790569415042095, 0.04159451654038515)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.34616890763041164, 0.32387162103263195, 0.8673783579037755)
#
# Awake: 0
# Faces: 1
# (0.14791375932615672, 0.125, 0.029399051601892736)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.16552117772047362, 0.15, 0.0)
#
# Awake: 0
# Faces: 1
# (0.25335270359176765, 0.2388450959634127, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2496821881329554, 0.2996257016633534, 0.12488526844760098)
#
# Awake: 0
# Faces: 1
# (0.15702717677706413, 0.16666666666666666, 0.041576537496303176)
#
# Awake: 0
# Faces: 1
# (0.25617014275584565, 0.22766042320237156, 0.16274669424134697)
#
# Awake: 0
# Faces: 1
# (0.17091083136448731, 0.1538647306476965, 0.041576537496303176)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2500699785637325, 0.24135404574916758, 0.08469711416439278)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2805283198220218, 0.2530294240356804, 0.21339479988815996)
#
# Awake: 0
# Faces: 1
# (0.16127417724876889, 0.14655482882269746, 0.029411764705882353)
#
# Awake: 0
# Faces: 1
# (0.11094003924504582, 0.15329238620669328, 0.029361010975735173)
#
# Awake: 0
# Faces: 1
# (0.23529411764705882, 0.25460333819405395, 0.08061138223506886)
#
# Awake: 0
# Faces: 1
# (0.1313548918227579, 0.16483082307670552, 0.031992834407549194)
#
# Awake: 0
# Faces: 1
# (0.1452223967283886, 0.12167605132909617, 0.0)
#
# Awake: 0
# Faces: 1
# (0.34566186625242745, 0.3379189091915237, 0.72)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.17845765256206245, 0.2158132119814573, 0.03412949405703812)
#
# Awake: 0
# Faces: 1
# (0.31806809832974015, 0.3333333333333333, 0.4829038818668629)
#
# Awake: 0
# Faces: 1
# (0.3631058272528683, 0.320988466826728, 0.035967500063280325)
#
# Awake: 0
# Faces: 1
# (0.11094003924504582, 0.14221363894199315, 0.0)
#
# Awake: 0
# Faces: 1
# (0.15732919388188818, 0.15892681321527494, 0.03125)
#
# Awake: 0
# Faces: 1
# (0.16580886821007096, 0.15455418600896656, 0.0)
#
# Awake: 0
# Faces: 1
# (0.30952380952380953, 0.3329560459081458, 0.12488526844760098)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.22471927624751503, 0.24968808471946113, 0.32432432432432434)
#
# Awake: 0
# Faces: 1
# (0.06992581834412663, 0.1261886162812672, 0.0)
#
# Awake: 0
# Faces: 1
# (0.2876848221499576, 0.3178536264305499, 0.06237828615518053)
#
# Awake: 0
# Faces: 1
# (0.25, 0.2403700850309326, 0.7586206896551724)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.2777777777777778, 0.30738052751370193, 0.0)
#
# Awake: 0
# Faces: 1
# (0.25, 0.24968808471946113, 0.7643753416492111)
#
# Awake: 0
# Faces: 1
# (0.17616606585441102, 0.17091083136448731, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3119251469460218, 0.29851115706299675, 0.7071067811865475)
#
# Awake: 0
# Faces: 1
# (0.325, 0.2724459655118999, 0.7358821178351062)
#
# Awake: 0
# Faces: 1
# (0.2773500981126146, 0.31796743500784785, 0.0)
#
# Awake: 0
# Faces: 1
# (0.3055555555555556, 0.3007732496038529, 0.6228410989030497)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.22471927624751503, 0.19253606842154392, 0.8382736442849092)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3, 0.31114177726023884, 0.0)
#
# Awake: 0
# Faces: 0
# Awake: 0
# Faces: 1
# (0.3162203479667375, 0.24018068605679, 0.7561882550236293)
#
# Awake: 0
# Faces: 2
# (0.23631256084527205, 0.2944941648078951, 0.21374114996372895)
#
# Awake: 0
# Faces: 1
# (0.4322057589160017, 0.3862480968484565, 0.0)
#
# Awake: 0
# Faces: 1
# ...
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3235294117647059, 0.3523649724724399, 0.06049506040189035)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3197029007553438, 0.3495633186072456, 0.024968808471946116)
#
# Awake: 1
# Faces: 1
# (0.34380736630734476, 0.3663967458131496, 0.029361010975735173)
#
# Awake: 1
# Faces: 1
# (0.3197029007553438, 0.3312945782245396, 0.028524895269256473)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.22376876883610253, 0.256073759865792, 0.0298142396999972)
#
# Awake: 1
# Faces: 1
# (0.24253562503633297, 0.23493192232525165, 0.030082841879809342)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.375, 0.29065658392992416, 0.0292103118918493)
#
# Awake: 1
# Faces: 1
# (0.24087440257466058, 0.24135404574916758, 0.041522739926869986)
#
# Awake: 1
# Faces: 1
# (0.35, 0.3586942162008005, 0.023255813953488372)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.29411764705882354, 0.3009644230527352, 0.25)
#
# Awake: 1
# Faces: 1
# (0.2660760420950957, 0.28964222318174615, 0.15846382194552627)
#
# Awake: 1
# Faces: 1
# (0.35133779719023495, 0.35, 0.048765984909417075)
#
# Awake: 1
# Faces: 1
# (0.23282599091286532, 0.23608834134288123, 0.17845765256206242)
#
# Awake: 1
# Faces: 1
# (0.36977945249146443, 0.3682566754559761, 0.06573827785585624)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.25, 0.23748180452882298, 0.04254356298115171)
#
# Awake: 1
# Faces: 1
# (0.23529411764705882, 0.24252877206220882, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3055555555555556, 0.31838634237934677, 0.06565321642986127)
#
# Awake: 1
# Faces: 1
# (0.325, 0.28638893798427906, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.3310656539720239, 0.6328052448234813)
#
# Awake: 1
# Faces: 1
# (0.3547621232692877, 0.3333333333333333, 0.06651901052377393)
#
# Awake: 1
# Faces: 1
# (0.18927285376081912, 0.22376876883610253, 0.029411764705882353)
#
# Awake: 1
# Faces: 1
# (0.3611111111111111, 0.3676073110469039, 0.09302605094190634)
#
# Awake: 1
# Faces: 1
# (0.279078152825719, 0.3235862900605597, 0.029098798098966275)
#
# Awake: 1
# Faces: 1
# (0.2894736842105263, 0.29065658392992416, 0.09805806756909202)
#
# Awake: 1
# Faces: 1
# (0.2571922625628131, 0.282842712474619, 0.0)
#
# Awake: 1
# Faces: 1
# (0.35294117647058826, 0.3310656539720239, 0.0)
#
# Awake: 1
# Faces: 1
# (0.1800020524176937, 0.19174124721184263, 0.06987712429686843)
#
# Awake: 1
# Faces: 1
# (0.35294117647058826, 0.295378269592824, 0.2936101097573517)
#
# Awake: 1
# Faces: 1
# (0.26424909878161656, 0.2600629835158737, 0.09053574604251853)
#
# Awake: 1
# Faces: 1
# (0.40105543734429894, 0.377136510409147, 0.0)
#
# Awake: 1
# Faces: 1
# (0.2773500981126146, 0.24235206811450272, 0.031189143077590267)
#
# Awake: 1
# Faces: 1
# (0.19425717247145285, 0.24087440257466058, 0.09582659576267817)
#
# Awake: 1
# Faces: 1
# (0.3155943597997745, 0.3061715012479187, 0.48056933133221275)
#
# Awake: 1
# Faces: 1
# (0.38636363636363635, 0.4725818566883412, 0.024929982747211407)
#
# Awake: 1
# Faces: 1
# (0.2462678125181665, 0.23608834134288123, 0.06057825328153827)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3716470731235832, 0.3682566754559761, 0.1278520779891897)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.32596360383230055, 0.3584654851895835, 0.11744404390294069)
#
# Awake: 1
# Faces: 1
# (0.25, 0.20447218324294508, 0.04254356298115171)
#
# Awake: 1
# Faces: 1
# (0.24596386043597826, 0.26424909878161656, 0.029961075885598987)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.18927285376081912, 0.22360679774997896, 0.04419417382415922)
#
# Awake: 1
# Faces: 1
# (0.3350254240920351, 0.3329560459081458, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.34022554968363894, 0.06237828615518053)
#
# Awake: 1
# Faces: 1
# (0.24961508830135312, 0.251869619194744, 0.3022438607339301)
#
# Awake: 1
# Faces: 1
# (0.3630852169962632, 0.385544883095949, 0.030178582014172842)
#
# Awake: 1
# Faces: 1
# (0.25335270359176765, 0.2004094170098539, 0.07179581586177382)
#
# Awake: 1
# Faces: 1
# (0.30738052751370193, 0.31405435355412825, 0.10338682751933664)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3599094457109207, 0.3567386206158705, 0.0)
#
# Awake: 1
# Faces: 1
# (0.2222222222222222, 0.23727844885472751, 0.3665567521632638)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2534196007116017, 0.26251151214901425, 0.04014478229518502)
#
# Awake: 1
# Faces: 1
# (0.14952135781726322, 0.1810714920850371, 0.04552514536059855)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3, 0.3181818181818182, 0.029399051601892736)
#
# Awake: 1
# Faces: 1
# (0.23488808780588138, 0.2430243358916866, 0.02838664779018298)
#
# Awake: 1
# Faces: 1
# (0.2518868125783982, 0.1643989873053573, 0.031189143077590267)
#
# Awake: 1
# Faces: 1
# (0.23488808780588138, 0.23748180452882298, 0.0)
#
# Awake: 1
# Faces: 1
# (0.2557041559783794, 0.26545609082651794, 0.030082841879809342)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3266609919029693, 0.3329560459081458, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2222222222222222, 0.2336824951347944, 0.349890676242843)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.23488808780588138, 0.25, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3625261940057528, 0.3584654851895835, 0.0)
#
# Awake: 1
# Faces: 1
# (0.33464622145315104, 0.3178536264305499, 0.02855977389887699)
#
# Awake: 1
# Faces: 1
# (0.22188007849009164, 0.2693811516220012, 0.27906976744186046)
#
# Awake: 1
# Faces: 1
# (0.38169314268455723, 0.36118735787391326, 0.06974104408145883)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.22376876883610253, 0.26402867467729757, 0.03125)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3409090909090909, 0.418739138072171, 0.025565499628245683)
#
# Awake: 1
# Faces: 1
# (0.3553753685381829, 0.30637894071415156, 0.3077145133220189)
#
# Awake: 1
# Faces: 1
# (0.24596386043597826, 0.2055270768301462, 0.0292103118918493)
#
# Awake: 1
# Faces: 1
# (0.3157894736842105, 0.34826301657349623, 0.09074259060283552)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3630852169962632, 0.3676073110469039, 0.058595873530904764)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.18927285376081912, 0.19425717247145285, 0.03125)
#
# Awake: 1
# Faces: 1
# (0.32297112073308687, 0.3005235936991301, 0.030289126640769135)
#
# Awake: 1
# Faces: 1
# (0.2571922625628131, 0.26984202646986644, 0.0282842712474619)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.31407645648142984, 0.06933752452815364)
#
# Awake: 1
# Faces: 1
# (0.23282599091286532, 0.2388450959634127, 0.06573827785585624)
#
# Awake: 1
# Faces: 1
# (0.27465689319140724, 0.2883505980845719, 0.042776467438466456)
#
# Awake: 1
# Faces: 1
# (0.40155644370746374, 0.3953322032552918, 0.025507216374642365)
#
# Awake: 1
# Faces: 1
# (0.23488808780588138, 0.2767114301352826, 0.060357164028345685)
#
# Awake: 1
# Faces: 1
# (0.3235294117647059, 0.3172985682222456, 0.5816675875859313)
#
# Awake: 1
# Faces: 1
# (0.29411764705882354, 0.3276399009264621, 0.6158164269043772)
#
# Awake: 1
# Faces: 1
# (0.325, 0.2876848221499576, 0.027681826617913324)
#
# Awake: 1
# Faces: 1
# (0.3328201177351375, 0.3310656539720239, 0.03219113899898252)
#
# Awake: 1
# Faces: 1
# (0.21280831802947608, 0.26545609082651794, 0.029098798098966275)
#
# Awake: 1
# Faces: 1
# (0.3684210526315789, 0.3676073110469039, 0.06933752452815364)
#
# Awake: 1
# Faces: 1
# (0.19611613513818404, 0.22376876883610253, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3235294117647059, 0.3529412620251612, 0.031008683647302117)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.36055512754639896, 0.32515496471407135, 0.02855977389887699)
#
# Awake: 1
# Faces: 1
# (0.18927285376081912, 0.1810714920850371, 0.17231137919889442)
#
# Awake: 1
# Faces: 1
# (0.24253562503633297, 0.2877543184223316, 0.030178582014172842)
#
# Awake: 1
# Faces: 1
# (0.22338530270442003, 0.18760816441715747, 0.0)
#
# Awake: 1
# Faces: 1
# (0.35, 0.3807120206682936, 0.023802777946288958)
#
# Awake: 1
# Faces: 1
# (0.2978879006693419, 0.24961508830135312, 0.029399051601892736)
#
# Awake: 1
# Faces: 1
# (0.34375, 0.3132782087446724, 0.043852900965351466)
#
# Awake: 1
# Faces: 1
# (0.36791183185934573, 0.35133779719023495, 0.0)
#
# Awake: 1
# Faces: 1
# (0.24445060351935236, 0.256073759865792, 0.33310494458892237)
#
# Awake: 1
# Faces: 1
# (0.32596360383230055, 0.30366582275446435, 0.29075089419334005)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2388450959634127, 0.23838910956858161, 0.04343722427630694)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3328201177351375, 0.3162203479667375, 0.028524895269256473)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2647058823529412, 0.23748180452882298, 0.0292103118918493)
#
# Awake: 1
# Faces: 1
# (0.31535299873658207, 0.343975468733302, 0.02499219116020307)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.38847237299173903, 0.02855977389887699)
#
# Awake: 1
# Faces: 1
# (0.3716470731235832, 0.3245945101352995, 0.03445204812747773)
#
# Awake: 1
# Faces: 1
# (0.3055555555555556, 0.30637894071415156, 0.06957205656856127)
#
# Awake: 1
# Faces: 1
# (0.3055555555555556, 0.3379189091915237, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3687817782917155, 0.47526112460303876, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3350254240920351, 0.3178536264305499, 0.028467047115478598)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.29702998569390543, 0.289134087584324, 0.07437051466359121)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2777777777777778, 0.3310656539720239, 0.06365425246889946)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.38005847503304596, 0.36496126001464235, 0.025565499628245683)
#
# Awake: 1
# Faces: 1
# (0.29411764705882354, 0.3237309501333119, 0.057049790538512946)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3922322702763681, 0.41424750300298735, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3125, 0.29264061094811233, 0.0)
#
# Awake: 1
# Faces: 1
# (0.305085107923876, 0.3419175385318709, 0.029361010975735173)
#
# Awake: 1
# Faces: 1
# (0.2208706236059213, 0.22188007849009164, 0.030082841879809342)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.22209280215830052, 0.23057714154256728, 0.031189143077590267)
#
# Awake: 1
# Faces: 1
# (0.3329560459081458, 0.39093501848676243, 0.02701716134791496)
#
# Awake: 1
# Faces: 1
# (0.2650854018430103, 0.2660293096304744, 0.026938622922018266)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.35714285714285715, 0.31946713798225884, 0.6428571428571429)
#
# Awake: 1
# Faces: 1
# (0.30738052751370193, 0.3310656539720239, 0.06237828615518053)
#
# Awake: 1
# Faces: 1
# (0.33464622145315104, 0.3040605699341486, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2774754878398196, 0.30056995195306196, 0.030082841879809342)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.24951314462072213, 0.28850527439451606, 0.029361010975735173)
#
# Awake: 1
# Faces: 1
# (0.26539634065922857, 0.2631578947368421, 0.05590169943749475)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.38169314268455723, 0.3328201177351375, 0.04267895997763199)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.3419175385318709, 0.04025848411142373)
#
# Awake: 1
# Faces: 1
# (0.3531122757732243, 0.36467477671134946, 0.4366997590725877)
#
# Awake: 1
# Faces: 1
# (0.3922322702763681, 0.3965283494032832, 0.02630668208823282)
#
# Awake: 1
# Faces: 1
# (0.2036073849504067, 0.24399546594670454, 0.04478859290223893)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.3379189091915237, 0.04025848411142373)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.275, 0.31535299873658207, 0.03288868749704872)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2647058823529412, 0.295378269592824, 0.029297936765452382)
#
# Awake: 1
# Faces: 1
# (0.38235294117647056, 0.31622776601683794, 0.0292103118918493)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.36791183185934573, 0.4, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3245945101352995, 0.33464622145315104, 0.02855977389887699)
#
# Awake: 1
# Faces: 1
# (0.3237309501333119, 0.275, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3914059881721716, 0.41377035253120426, 0.026171196129510688)
#
# Awake: 1
# Faces: 1
# (0.33563229250828386, 0.31776400430001744, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3603172752420006, 0.36608826607349904, 0.0)
#
# Awake: 1
# Faces: 1
# (0.31114177726023884, 0.3178536264305499, 0.029411764705882353)
#
# Awake: 1
# Faces: 1
# (0.17647058823529413, 0.2523772325625344, 0.0)
#
# Awake: 1
# Faces: 1
# (0.2388450959634127, 0.28221369986144007, 0.03052812554363318)
#
# Awake: 1
# Faces: 1
# (0.3328201177351375, 0.3287979746107146, 0.44034471909426637)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.28539089649269644, 0.31946713798225884, 0.029411764705882353)
#
# Awake: 1
# Faces: 1
# (0.3, 0.3312945782245396, 0.04998438232040614)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.31622776601683794, 0.04143353952325209)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3237309501333119, 0.33357947635520163, 0.0)
#
# Awake: 1
# Faces: 1
# (0.37072370908057856, 0.3922322702763681, 0.026279416561381837)
#
# Awake: 1
# Faces: 1
# (0.19108411851099838, 0.16580886821007096, 0.03331483023263848)
#
# Awake: 1
# Faces: 1
# (0.29411764705882354, 0.29251024638728507, 0.04410810913912309)
#
# Awake: 1
# Faces: 1
# (0.3157894736842105, 0.3173734462834955, 0.029098798098966275)
#
# Awake: 1
# Faces: 1
# (0.29361010975735174, 0.28154625318573645, 0.029411764705882353)
#
# Awake: 1
# Faces: 1
# (0.29851115706299675, 0.28539089649269644, 0.0)
#
# Awake: 1
# Faces: 1
# (0.26021731499210743, 0.2805283198220218, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3055555555555556, 0.3670378128763776, 0.028467047115478598)
#
# Awake: 1
# Faces: 1
# (0.35233213170882205, 0.3032086372512131, 0.41503746524979596)
#
# Awake: 1
# Faces: 1
# (0.3055555555555556, 0.3333333333333333, 0.0)
#
# Awake: 1
# Faces: 1
# (0.29411764705882354, 0.3419175385318709, 0.030178582014172842)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3, 0.28539089649269644, 0.023749016662636548)
#
# Awake: 1
# Faces: 1
# (0.36467477671134946, 0.4090909090909091, 0.0)
#
# Awake: 1
# Faces: 1
# (0.23850259343081628, 0.24252877206220882, 0.0)
#
# Awake: 1
# Faces: 1
# (0.292103118918493, 0.2767114301352826, 0.06049506040189035)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.31796743500784785, 0.3333333333333333, 0.04034029375505465)
#
# Awake: 1
# Faces: 1
# (0.18318582636182795, 0.20950310663581354, 0.4437601569801833)
#
# Awake: 1
# Faces: 1
# (0.3351155373249634, 0.306420415705138, 0.04410810913912309)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.3333333333333333, 0.030178582014172842)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.2996257016633534, 0.34197094625202445, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3625261940057528, 0.37304110110653627, 0.0292103118918493)
#
# Awake: 1
# Faces: 1
# (0.3235294117647059, 0.34007021872693166, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.2668948795168779, 0.029361010975735173)
#
# Awake: 1
# Faces: 1
# (0.3264417503997878, 0.3213134308103423, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3611111111111111, 0.3016921834310232, 0.06957205656856127)
#
# Awake: 1
# Faces: 1
# (0.3529412620251612, 0.3312945782245396, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3611111111111111, 0.3333333333333333, 0.0)
#
# Awake: 1
# Faces: 1
# (0.36341007028606165, 0.33475616819419246, 0.03087537605472192)
#
# Awake: 1
# Faces: 1
# (0.23535403452072196, 0.21280831802947608, 0.15151515151515152)
#
# Awake: 1
# Faces: 1
# (0.3181818181818182, 0.3200921998322399, 0.027735009811261455)
#
# Awake: 1
# Faces: 1
# (0.3430805738534929, 0.3312945782245396, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3834824944236852, 0.38052119532359524, 0.027767067240353285)
#
# Awake: 1
# Faces: 1
# (0.3125, 0.3032086372512131, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3055555555555556, 0.30411126135284217, 0.09086737992230741)
#
# Awake: 1
# Faces: 1
# (0.33741095691478934, 0.31575792550193144, 0.0)
#
# Awake: 1
# Faces: 1
# (0.225, 0.23782574707724702, 0.02630668208823282)
#
# Awake: 1
# Faces: 1
# (0.1860521018838127, 0.22127080340213676, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3553753685381829, 0.3312945782245396, 0.06049506040189035)
#
# Awake: 1
# Faces: 1
# (0.35133779719023495, 0.3567386206158705, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3333333333333333, 0.3419175385318709, 0.20072391147592508)
#
# Awake: 1
# Faces: 1
# (0.23488808780588138, 0.27384811582540314, 0.058595873530904764)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.31796743500784785, 0.31405435355412825, 0.02855977389887699)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.27465689319140724, 0.27607881518711636, 0.029411764705882353)
#
# Awake: 1
# Faces: 1
# (0.3235294117647059, 0.30597159483648995, 0.06763553368079128)
#
# Awake: 1
# Faces: 1
# (0.29702998569390543, 0.28850527439451606, 0.0)
#
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 0
# Awake: 1
# Faces: 1
# (0.3071475584169756, 0.2788125341864264, 0.0)
#
# Awake: 1
# Faces: 1
# (0.3529412620251612, 0.3032086372512131, 0.3415086756140032)
#
# Awake: 1
# Faces: 1
# (0.12269441465520421, 0.14705882352941177, 0.36791183185934573)
