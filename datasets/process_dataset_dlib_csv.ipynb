# %%
import cv2
import imutils
from imutils import face_utils
import dlib
import glob2
import matplotlib.pyplot as plt
import pandas as pd
from scipy.spatial import distance as dist

# %%
DATASET = './dmd/binary_labels_lite'
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('dlib/shape_predictor_68_face_landmarks.dat')

EYE_AR_THRESH = 0.3
MOUTH_AR_THRESH = 0.2

# %%
def mouth_aspect_Ratio(mouth):
    A = dist.euclidean(mouth[1], mouth[7])
    B = dist.euclidean(mouth[3], mouth[5])
    C = dist.euclidean(mouth[0], mouth[4])
    mar = (A + B) / (2.0 * C)
    return mar

def eye_aspect_ratio(eye):
    A = dist.euclidean(eye[1], eye[5])
    B = dist.euclidean(eye[2], eye[4])
    C = dist.euclidean(eye[0], eye[3])
    ear = (A + B) / (2.0 * C)
    return ear

# %%
def detect_face_landmarks(frame):

    # cv2.imshow('Frame', frame)
    frame = imutils.resize(frame, width=640)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # detect faces
    faces = detector(gray, 1)
    print(f"Faces detected: {len(faces)}")

    if len(faces) == 0:
        return None

    # get the largest face
    largest_face = None;
    for face in faces:
        largest_face_area = 0;
        if face.area() > largest_face_area:
            largest_face = face

    (lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS['left_eye']
    (rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS['right_eye']
    (mStart, mEnd) = face_utils.FACIAL_LANDMARKS_IDXS['inner_mouth']

    # determine the facial landmarks for the face region, then
    # convert the facial landmark (x, y)-coordinates to a NumPy
    # array
    shape = predictor(gray, largest_face)
    shape = face_utils.shape_to_np(shape)

    # extract the left and right eye coordinates, then use the
    # coordinates to compute the eye aspect ratio for both eyes
    leftEye = shape[lStart:lEnd]
    rightEye = shape[rStart:rEnd]
    mouth = shape[mStart:mEnd]
    leftEAR = eye_aspect_ratio(leftEye)
    rightEAR = eye_aspect_ratio(rightEye)
    mouthAR = mouth_aspect_Ratio(mouth)
    print(f"LEFT EYE AR: {leftEAR}")
    print(f"RIGHT EYE AR: {rightEAR}")
    print(f"MOUTH AR: {mouthAR}")

    # average the eye aspect ratio together for both eyes
    ear = (leftEAR + rightEAR) / 2.0

    if ear < EYE_AR_THRESH and mouthAR < MOUTH_AR_THRESH:
        print(f"Eyes closed and mouth closed: DROSWY")
    if ear < EYE_AR_THRESH and mouthAR > MOUTH_AR_THRESH:
        print(f"Eyes closed and mouth opened: DROWSY")
    if ear > EYE_AR_THRESH and mouthAR > MOUTH_AR_THRESH:
        print(f"Eyes opened and mouth opened (yawn): AWAKE")
    if ear > EYE_AR_THRESH and mouthAR < MOUTH_AR_THRESH:
        print(f"Eyes opened and mouth closed: AWAKE")

    # compute the convex hull for the left and right eye, then
    # visualize each of the eyes
    leftEyeHull = cv2.convexHull(leftEye)
    rightEyeHull = cv2.convexHull(rightEye)
    mouthHull = cv2.convexHull(mouth)
    cv2.drawContours(frame, [leftEyeHull], -1, (0, 255, 0), 1)
    cv2.drawContours(frame, [rightEyeHull], -1, (0, 255, 0), 1)
    cv2.drawContours(frame, [mouthHull], -1, (0, 255, 0), 1)

    return frame

# %%
file_paths = glob2.glob(DATASET + '/**/*.jpg')

for i, file_path in enumerate(file_paths):
    print(f"File input path: {file_path}")
    img = cv2.imread(file_path)
    img = detect_face_landmarks(img)
    if img is not None:
        plt.imshow(img)
        plt.show()
        print ('\n')
# Out:
# File input path: ./dmd/binary_labels_lite/drowsy/3569.jpg
# Faces detected: 1
# LEFT EYE AR: 0.2773500981126146
# RIGHT EYE AR: 0.26279416561381835
# MOUTH AR: 0.724548207614287
# Eyes closed and mouth opened: DROWSY
# File input path: ./dmd/binary_labels_lite/drowsy/3447.jpg
# Faces detected: 1
# LEFT EYE AR: 0.16127417724876889
# RIGHT EYE AR: 0.14907119849998599
# MOUTH AR: 0.75
# Eyes closed and mouth opened: DROWSY
# File input path: ./dmd/binary_labels_lite/drowsy/1053.jpg
# Faces detected: 1
# LEFT EYE AR: 0.16101915080209417
# RIGHT EYE AR: 0.19665385615732067
# MOUTH AR: 0.015041420939904671
# Eyes closed and mouth closed: DROSWY
# File input path: ./dmd/binary_labels_lite/drowsy/3457.jpg
# Faces detected: 1
# LEFT EYE AR: 0.28788315742461756
# RIGHT EYE AR: 0.27363522730774703
# MOUTH AR: 0.6286394011976746
# Eyes closed and mouth opened: DROWSY
# File input path: ./dmd/binary_labels_lite/drowsy/2779.jpg
# Faces detected: 1
# LEFT EYE AR: 0.1168412475673972
# ...
