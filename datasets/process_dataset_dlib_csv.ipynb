# %%
import os
import cv2
import imutils
from imutils import face_utils
import dlib
import glob2
import matplotlib.pyplot as plt
import pandas as pd
from scipy.spatial import distance as dist

# %%
DATASET = './dmd/binary_labels'
CSV_FILE = 'landmarks.csv'
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor('dlib/shape_predictor_68_face_landmarks.dat')

EYE_AR_THRESH = 0.3
MOUTH_AR_THRESH = 0.2

# %%
# def mouth_aspect_Ratio(mouth):
#     A = dist.euclidean(mouth[1], mouth[7])
#     B = dist.euclidean(mouth[3], mouth[5])
#     C = dist.euclidean(mouth[0], mouth[4])
#     mar = (A + B) / (2.0 * C)
#     return mar
#
# def eye_aspect_ratio(eye):
#     A = dist.euclidean(eye[1], eye[5])
#     B = dist.euclidean(eye[2], eye[4])
#     C = dist.euclidean(eye[0], eye[3])
#     ear = (A + B) / (2.0 * C)
#     return ear

# %%
def get_landmarks(frame):

    frame = imutils.resize(frame, width=640)
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # List to hold coordinates
    landmarks_list = []

    # detect faces
    # faces = detector(gray,1)
    faces = detector(gray)

    if len(faces) == 0:
        return None

    # get the largest face
    largest_face = None;
    for face in faces:
        largest_face_area = 0;
        if face.area() > largest_face_area:
            largest_face = face

    # initalize FACIAL_LANDMARKS indexes
    # (lStart, lEnd) = face_utils.FACIAL_LANDMARKS_IDXS['left_eye']
    # (rStart, rEnd) = face_utils.FACIAL_LANDMARKS_IDXS['right_eye']
    # (mStart, mEnd) = face_utils.FACIAL_LANDMARKS_IDXS['inner_mouth']

    # determine the facial landmarks for the face region, then
    # array

    shape = predictor(gray, largest_face)
    # shape = face_utils.shape_to_np(shape)

    # Individual landmarks
    left_eye = [None]*12  # 6 points * 2 coordinates
    right_eye = [None]*12  # 6 points * 2 coordinates
    inner_mouth = [None]*16  # 8 points * 2 coordinates

    # extract the left and right eye coordinates, then use the
    # coordinates to compute the eye aspect ratio for both eyes
    # leftEye = shape[lStart:lEnd]
    # rightEye = shape[rStart:rEnd]
    # mouth = shape[mStart:mEnd]

    # Loop over the (x, y)-coordinates for the facial landmarks
    for i in range(36, 42):  # left eye landmarks
        left_eye[(i-36)*2] = shape.part(i).x
        left_eye[(i-36)*2 + 1] = shape.part(i).y

    for i in range(42, 48):  # right eye landmarks
        right_eye[(i-42)*2] = shape.part(i).x
        right_eye[(i-42)*2 + 1] = shape.part(i).y

    for i in range(60, 68):  # inner mouth landmarks
        inner_mouth[(i-60)*2] = shape.part(i).x
        inner_mouth[(i-60)*2 + 1] = shape.part(i).y

    # Append to landmarks list
    landmarks_list.append(left_eye + right_eye + inner_mouth)

    # leftEAR = eye_aspect_ratio(leftEye)
    # rightEAR = eye_aspect_ratio(rightEye)
    # mouthAR = mouth_aspect_Ratio(mouth)
    # print(f"LEFT EYE AR: {leftEAR}")
    # print(f"RIGHT EYE AR: {rightEAR}")
    # print(f"MOUTH AR: {mouthAR}")

    # average the eye aspect ratio together for both eyes
    # ear = (leftEAR + rightEAR) / 2.0

    # if ear < EYE_AR_THRESH and mouthAR < MOUTH_AR_THRESH:
    #     print(f"Eyes closed and mouth closed: DROSWY")
    # if ear < EYE_AR_THRESH and mouthAR > MOUTH_AR_THRESH:
    #     print(f"Eyes closed and mouth opened: DROWSY")
    # if ear > EYE_AR_THRESH and mouthAR > MOUTH_AR_THRESH:
    #     print(f"Eyes opened and mouth opened (yawn): AWAKE")
    # if ear > EYE_AR_THRESH and mouthAR < MOUTH_AR_THRESH:
    #     print(f"Eyes opened and mouth closed: AWAKE")

    # compute the convex hull for the left and right eye, then
    # visualize each of the eyes
    # leftEyeHull = cv2.convexHull(leftEye)
    # rightEyeHull = cv2.convexHull(rightEye)
    # mouthHull = cv2.convexHull(mouth)
    # cv2.drawContours(frame, [leftEyeHull], -1, (0, 255, 0), 1)
    # cv2.drawContours(frame, [rightEyeHull], -1, (0, 255, 0), 1)
    # cv2.drawContours(frame, [mouthHull], -1, (0, 255, 0), 1)


    # return coordinates, frame

    # Return an empty list if no faces are detected
    return landmarks_list if len(landmarks_list) > 0 else []

# %%
if os.path.exists(CSV_FILE):
    csv = pd.read_csv
else:
    file_paths = glob2.glob(DATASET + '/**/*.jpg')
    rows = []

    for i, file_path in enumerate(file_paths):

        label = 'awake' if 'awake' in file_path else 'drowsy'
        img = cv2.imread(file_path)
        landmarks = get_landmarks(img)

        if img is not None and landmarks is not None:
            for landmark in landmarks:
                row = ['image', *landmark, label]
                rows.append(row)
                print(f"{row}\n")

    df = pd.DataFrame(rows, columns=['image'] + [f'point_{i}' for i in range(1, 41)] + ['label'])
    df.to_csv('landmarks.csv', index=False)

# %%
df.head()
# Out:
#    image  point_1  point_2  point_3  point_4  point_5  point_6  point_7  \
# 0  image      267      174      273      171      278      170      284
# 1  image      276      199      282      196      289      195      296
# 2  image      252      208      258      204      265      203      271
# 3  image      284      162      290      155      299      155      306
# 4  image      266      201      271      198      278      197      285
#
#    point_8  point_9  ...  point_32  point_33  point_34  point_35  point_36  \
# 0      173      278  ...       219       321       225       308       232
# 1      197      289  ...       245       327       247       318       245
# 2      207      265  ...       258       303       269       295       276
# 3      161      299  ...       225       344       226       333       229
# 4      199      278  ...       247       319       249       310       250
#
#    point_37  point_38  point_39  point_40   label
# ...
