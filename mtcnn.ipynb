# %%
from mtcnn.mtcnn import MTCNN
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import load_model  # Update import statement
from sklearn.model_selection import train_test_split
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, BatchNormalization, MaxPooling2D, Dropout  # Update import statement
import matplotlib.pyplot as plt
import os
import pickle
from glob import glob
from tqdm import tqdm
from PIL import Image
import numpy as np
from sklearn.metrics import confusion_matrix
import seaborn as sns
import pandas as pd
import cv2

# %%
FOLDER_IMAGES = './datasets/dmd/binary_labels'

# %%
def crop_image(image_path, bounding_box):
    image = cv2.imread(image_path)
    x1, y1, x2, y2 = bounding_box['box']
    cropped_image = image[y1:y2, x1:x2]
    return cropped_image

# %%
detector = MTCNN()

image = plt.imread('./datasets/dmd/binary_labels_test/0.jpg')
faces = detector.detect_faces(image)
for face in faces:
    print(face)
# Out:
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 51ms/step
# 2023-06-01 13:05:58.682472: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 12ms/step
# 7/7 [==============================] - 0s 2ms/step
# 1/1 [==============================] - 0s 63ms/step
# {'box': [106, 56, 201, 222], 'confidence': 0.9998352527618408, 'keypoints': {'left_eye': (153, 178), 'right_eye': (221, 138), 'nose': (196, 226), 'mouth_left': (209, 264), 'mouth_right': (265, 232)}}
